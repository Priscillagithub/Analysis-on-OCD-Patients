# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Patient ID: A unique identifier for each patient in the dataset.
#
# Age: The age of the patient at the time of data collection.
#
# Gender: The gender of the patient (e.g., Male, Female).
#
# Ethnicity: The ethnic background of the patient (e.g., African, Hispanic, Asian, Caucasian).
#
# Marital Status: The marital status of the patient (e.g., Single, Married, Divorced).
#
# Education Level: The highest level of education completed by the patient (e.g., High School, Some College, College Degree, Graduate Degree).
#
# OCD Diagnosis Date: The date when the patient was diagnosed with Obsessive-Compulsive Disorder (OCD).
#
# Duration of Symptoms (months): The duration, in months, that the patient has been experiencing OCD symptoms up until the time of data collection.
#
# Previous Diagnoses: Any previous mental health diagnoses the patient has received before the OCD diagnosis (e.g., Major Depressive Disorder (MDD), Generalized Anxiety Disorder (GAD), Post-Traumatic Stress Disorder (PTSD), Panic Disorder, None).
#
# Family History of OCD: Indicates whether the patient has a family history of OCD (Yes/No).
#
# Obsession Type: The primary type of obsession experienced by the patient (e.g., Harm-related, Contamination, Symmetry, Hoarding, Religious).
#
# Compulsion Type('being forced to do something'): The primary type of compulsion performed by the patient in response to their obsessions (e.g., Checking, Washing, Ordering, Praying, Counting).
#
# Y-BOCS Score (Obsessions): The score related to the severity of the patient's obsessions, measured by the Yale-Brown Obsessive Compulsive Scale (Y-BOCS). The Y-BOCS is a standardized scale used to assess the severity of OCD symptoms.
#
# Y-BOCS Score (Compulsions): The score related to the severity of the patient's compulsions, also measured by the Y-BOCS.
#
# Depression Diagnosis: Indicates whether the patient has a diagnosis of depression (Yes/No).
#
# Anxiety Diagnosis: Indicates whether the patient has a diagnosis of anxiety (Yes/No).
#
# Medications: The type of medication the patient is currently taking for their mental health conditions (e.g., Selective Serotonin Reuptake Inhibitors (SSRI), Serotonin-Norepinephrine Reuptake Inhibitors (SNRI), Benzodiazepine, None).

# %%
df = pd.read_csv('ocd_patient_dataset.csv')
df
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# ...

# %% [markdown]
# # Exploring the data.

# %% [markdown]
# ### Head

# %%
# Display first 5 rows.
df.head()
# Display first 10 rows. 
df.head(10)
# Display specific first rows.
df['Age'].head(10)
# Out:
# 0    32
# 1    69
# 2    57
# 3    27
# 4    56
# 5    32
# 6    38
# 7    57
# 8    36
# 9    72
# Name: Age, dtype: int64

# %% [markdown]
# ### Tail

# %%
# Display last 5 rows.
df.tail()
# Display last 10 rows.
df.tail(10)
# Display specific last rows.
df['Age'].tail(10)
# Out:
# 1490    58
# 1491    52
# 1492    40
# 1493    58
# 1494    72
# 1495    38
# 1496    19
# 1497    40
# 1498    37
# 1499    18
# Name: Age, dtype: int64

# %% [markdown]
# ### Shape

# %%
# It shows total no.of rows and total no.of columns.
print(df.shape)
# Out:
# (1500, 17)

# %% [markdown]
# ### columns

# %%
# It shows column names in df.
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Gender', 'Ethnicity', 'Marital Status',
#        'Education Level', 'OCD Diagnosis Date',
#        'Duration of Symptoms (months)', 'Previous Diagnoses',
#        'Family History of OCD', 'Obsession Type', 'Compulsion Type',
#        'Y-BOCS Score (Obsessions)', 'Y-BOCS Score (Compulsions)',
#        'Depression Diagnosis', 'Anxiety Diagnosis', 'Medications'],
#       dtype='object')

# %% [markdown]
# ### dataType

# %%
# It shows the type of dataset.
print(df.dtypes)
# Out:
# Patient ID                        int64
# Age                               int64
# Gender                           object
# Ethnicity                        object
# Marital Status                   object
# Education Level                  object
# OCD Diagnosis Date               object
# Duration of Symptoms (months)     int64
# Previous Diagnoses               object
# Family History of OCD            object
# Obsession Type                   object
# Compulsion Type                  object
# Y-BOCS Score (Obsessions)         int64
# Y-BOCS Score (Compulsions)        int64
# Depression Diagnosis             object
# Anxiety Diagnosis                object
# Medications                      object
# dtype: object

# %% [markdown]
# ### info

# %%
# It gives information about the null values,dtype,column names.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Patient ID                     1500 non-null   int64
#  1   Age                            1500 non-null   int64
#  2   Gender                         1500 non-null   object
#  3   Ethnicity                      1500 non-null   object
#  4   Marital Status                 1500 non-null   object
#  5   Education Level                1500 non-null   object
#  6   OCD Diagnosis Date             1500 non-null   object
#  7   Duration of Symptoms (months)  1500 non-null   int64
#  8   Previous Diagnoses             1500 non-null   object
#  9   Family History of OCD          1500 non-null   object
#  10  Obsession Type                 1500 non-null   object
#  11  Compulsion Type                1500 non-null   object
# ...

# %% [markdown]
# ### Describe

# %%
df.describe()
# Out:
#         Patient ID          Age  Duration of Symptoms (months)  \
# count  1500.000000  1500.000000                    1500.000000
# mean   5541.254000    46.781333                     121.745333
# std    2562.389469    16.830321                      67.404610
# min    1017.000000    18.000000                       6.000000
# 25%    3338.000000    32.000000                      64.000000
# 50%    5539.500000    47.000000                     121.000000
# 75%    7745.500000    61.000000                     178.000000
# max    9995.000000    75.000000                     240.000000
#
#        Y-BOCS Score (Obsessions)  Y-BOCS Score (Compulsions)
# count                1500.000000                  1500.00000
# mean                   20.048000                    19.62600
# std                    11.823884                    11.78287
# min                     0.000000                     0.00000
# 25%                    10.000000                     9.00000
# ...

# %%
df
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# ...

# %%
df.count() #It gives the total no of non null values.
# Out:
# Patient ID                       1500
# Age                              1500
# Gender                           1500
# Ethnicity                        1500
# Marital Status                   1500
# Education Level                  1500
# OCD Diagnosis Date               1500
# Duration of Symptoms (months)    1500
# Previous Diagnoses               1500
# Family History of OCD            1500
# Obsession Type                   1500
# Compulsion Type                  1500
# Y-BOCS Score (Obsessions)        1500
# Y-BOCS Score (Compulsions)       1500
# Depression Diagnosis             1500
# Anxiety Diagnosis                1500
# Medications                      1500
# dtype: int64

# %%
df['Age'].unique() # no of unique values.
# Out:
# array([32, 69, 57, 27, 56, 38, 36, 72, 21, 73, 23, 68, 48, 29, 25, 55, 50,
#        66, 62, 28, 43, 47, 74, 60, 22, 24, 70, 33, 41, 58, 65, 49, 37, 63,
#        46, 31, 64, 54, 61, 19, 71, 53, 52, 35, 51, 59, 42, 40, 39, 26, 75,
#        67, 34, 18, 45, 44, 20, 30], dtype=int64)

# %%
df['Age'].nunique() # total no of nunique values.
# Out:
# 58

# %%
# what are the unique in gender.

df['Gender'].unique()

# There are 2 unique values *Male* and *Female*.
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# What are the unique values in Previous Diagnoses.

df['Previous Diagnoses'].unique()

# There are 5 unique values in Previous Diagnoses.

# MDD :- major depressive disorder
# PTSD:- Post-Traumatic Stress Disorder (PTSD)
# GAD:-  Generalized Anxiety Disorder (GAD)
# Panic Disorder
# None
# Out:
# array(['MDD', 'None', 'PTSD', 'GAD', 'Panic Disorder'], dtype=object)

# %%
# What are the unique values in Obsession Type.

df['Obsession Type'].unique()

# Harm-related:- fear of — causing harm to yourself or others.
# Contamination:- the process of making something dirty.
# Symmetry:- In same way.
# Hoarding :- a mental health condition where -- store a large number of items, even if they have little or no value.
# Religious:- intrusive(making uncomfortable) thoughts about sin, blasphemous images, and excessive fears of punishment from God.
# Out:
# array(['Harm-related', 'Contamination', 'Symmetry', 'Hoarding',
#        'Religious'], dtype=object)

# %%
# what are the unique values in Compulsion Type.

df['Compulsion Type'].unique()

# This Compulsion Type is based on the Obsession (Ex:- *Contamination* means making dirty to be clean we *wash*. )
# Out:
# array(['Checking', 'Washing', 'Ordering', 'Praying', 'Counting'],
#       dtype=object)

# %%
# What are the unique values in Medication.

df['Medications'].unique()
# Out:
# array(['SNRI', 'SSRI', 'Benzodiazepine', 'None'], dtype=object)

# %%
df['Depression Diagnosis'].value_counts()
# Out:
# Yes    772
# No     728
# Name: Depression Diagnosis, dtype: int64

# %%
df['Anxiety Diagnosis'].value_counts() # It gives the unique values with their count.
# Out:
# Yes    751
# No     749
# Name: Anxiety Diagnosis, dtype: int64

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
# C:\Users\PRISCILLA\AppData\Local\Temp\ipykernel_14656\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                Patient ID       Age  \
# Patient ID                       1.000000  0.029146
# Age                              0.029146  1.000000
# Duration of Symptoms (months)   -0.026091 -0.001505
# Y-BOCS Score (Obsessions)        0.019816 -0.003162
# Y-BOCS Score (Compulsions)       0.024720  0.014137
#
#                                Duration of Symptoms (months)  \
# Patient ID                                         -0.026091
# Age                                                -0.001505
# Duration of Symptoms (months)                       1.000000
# Y-BOCS Score (Obsessions)                           0.007946
# ...

# %%
#  The above table represents the correlations between each (numeric)column of the data frame. 
#  The correlation between the self is 1.0, 
#  The negative correlation defined negative relationship means on increasing one column value second will decrease and vice-versa.
#  The zeros correlation defines no relationship I.e neutral. 
#  And positive correlations define positive relationships meaning on increasing one column value second will also increase and vice-versa.

# %%
# Interpretation

# **Correlation matrix** is used for relation between 2 variables for graphs.
# It is giveing only for numerical columns.

# Here there is no relationship between any columns.

# The correlation should between 0 and 1 but any column is not between 0.1 to 0.9
# In this case we need to check the nearest values.They are 0.04, 0.03, 0.02

# %%
#correlation map
f,ax = plt.subplots(figsize=(16, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.2f',ax=ax)
plt.show()
# Out:
# C:\Users\PRISCILLA\AppData\Local\Temp\ipykernel_14656\1829428607.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.2f',ax=ax)

# %%
df.rename(columns = ({'Y-BOCS Score (Compulsions)':'Y_BOCS_Score_Compulsions'}))
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# ...

# %%
# The Yale-Brown Obsessive Compulsive Scale (Y-BOCS) score is interpreted based on the range of the total score,
#    which can range from 0 to 40: 
# 0–7: Subclinical symptoms 
# 8–15: Mild symptoms 
# 16–23: Moderate symptoms 
# 24–31: Severe symptoms 
# 32–40: Extreme symptoms

# %%
# Function to classify the Y-BOCS Score (Compulsions)
def classify_ybocs_score(Y_BOCS_Score_Compulsions):
    if 0 <= Y_BOCS_Score_Compulsions <= 7:
        return 'Subclinical symptoms'
    elif 8 <= Y_BOCS_Score_Compulsions <= 15:
        return 'Mild symptoms'
    elif 16 <= Y_BOCS_Score_Compulsions <= 23:
        return 'Moderate symptoms'
    elif 24 <= Y_BOCS_Score_Compulsions <= 31:
        return 'Severe symptoms'
    elif 32 <= Y_BOCS_Score_Compulsions <= 40:
        return 'Extreme symptoms'
    else:
        return 'Invalid score'  # In case the score is outside the expected range

# Apply the function to classify each score
df['Y-BOCS Severity'] = df['Y-BOCS Score (Compulsions)'].apply(classify_ybocs_score)

### apply(classify_ybocs_score):

#The **.apply()** function is a Pandas method that applies a function to each element in a Series (or DataFrame).
#In this case, classify_ybocs_score is the function being applied.


# Display the classified DataFrame
print(df)
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# ...

# %%
# Rearrangeing the Columns.

df.loc[:,['Patient ID','Age','Gender','Ethnicity','Marital Status','Education Level','OCD Diagnosis Date','Duration of Symptoms (months)','Previous Diagnoses','Family History of OCD','Obsession Type','Compulsion Type','Y-BOCS Score (Obsessions)','Y-BOCS Score (Compulsions)','Y-BOCS Severity','Depression Diagnosis','Anxiety Diagnosis','Medications']]
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# ...

# %%
df.tail()
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# 1495         2019-01-10                             53                MDD
# 1496         2022-09-14                            160                GAD
# 1497         2018-03-13                            100               None
# 1498         2018-04-14                            210                GAD
# 1499         2020-12-23                             91               None
#
#      Family History of OCD Obsession Type Compulsion Type  \
# ...

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# #### Handling null values.

# %%
df.isnull()
# Out:
#       Patient ID    Age  Gender  Ethnicity  Marital Status  Education Level  \
# 0          False  False   False      False           False            False
# 1          False  False   False      False           False            False
# 2          False  False   False      False           False            False
# 3          False  False   False      False           False            False
# 4          False  False   False      False           False            False
# ...          ...    ...     ...        ...             ...              ...
# 1495       False  False   False      False           False            False
# 1496       False  False   False      False           False            False
# 1497       False  False   False      False           False            False
# 1498       False  False   False      False           False            False
# 1499       False  False   False      False           False            False
#
# ...

# %% [markdown]
# **Interpretation**
#
# * There is no null values in the dataset.

# %%
# Columns with NAN in True/False
df.isnull().any()
# Out:
# Patient ID                       False
# Age                              False
# Gender                           False
# Ethnicity                        False
# Marital Status                   False
# Education Level                  False
# OCD Diagnosis Date               False
# Duration of Symptoms (months)    False
# Previous Diagnoses               False
# Family History of OCD            False
# Obsession Type                   False
# Compulsion Type                  False
# Y-BOCS Score (Obsessions)        False
# Y-BOCS Score (Compulsions)       False
# Depression Diagnosis             False
# Anxiety Diagnosis                False
# Medications                      False
# Y-BOCS Severity                  False
# dtype: bool

# %%
# simply tells Null values is there are not.
df.isnull().any().any()
# Out:
# False

# %%
# total column wise null values. in integer
df.isna().sum()
# Out:
# Patient ID                       0
# Age                              0
# Gender                           0
# Ethnicity                        0
# Marital Status                   0
# Education Level                  0
# OCD Diagnosis Date               0
# Duration of Symptoms (months)    0
# Previous Diagnoses               0
# Family History of OCD            0
# Obsession Type                   0
# Compulsion Type                  0
# Y-BOCS Score (Obsessions)        0
# Y-BOCS Score (Compulsions)       0
# Depression Diagnosis             0
# Anxiety Diagnosis                0
# Medications                      0
# Y-BOCS Severity                  0
# dtype: int64

# %%
# It gives not null data.'TRUE' represent not having null values.
df.notna()
# Out:
#       Patient ID   Age  Gender  Ethnicity  Marital Status  Education Level  \
# 0           True  True    True       True            True             True
# 1           True  True    True       True            True             True
# 2           True  True    True       True            True             True
# 3           True  True    True       True            True             True
# 4           True  True    True       True            True             True
# ...          ...   ...     ...        ...             ...              ...
# 1495        True  True    True       True            True             True
# 1496        True  True    True       True            True             True
# 1497        True  True    True       True            True             True
# 1498        True  True    True       True            True             True
# 1499        True  True    True       True            True             True
#
# ...

# %% [markdown]
# # Converting GENDER column to 0 and 1

# %%
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

print(df.head())
# Out:
#    Patient ID  Age  Gender Ethnicity Marital Status Education Level  \
# 0        1018   32       1   African         Single    Some College
# 1        2406   69       0   African       Divorced    Some College
# 2        1188   57       0  Hispanic       Divorced  College Degree
# 3        6200   27       1  Hispanic        Married  College Degree
# 4        5824   56       1  Hispanic        Married     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# 0         2016-07-15                            203                MDD
# 1         2017-04-28                            180               None
# 2         2018-02-02                            173                MDD
# 3         2014-08-25                            126               PTSD
# 4         2022-02-20                            168               PTSD
#
#   Family History of OCD Obsession Type Compulsion Type  \
# 0                    No   Harm-related        Checking
# ...

# %% [markdown]
# # Converting GENDER column to male and female

# %%
df['Gender'] = df['Gender'].map({0: 'Male', 1: 'Female'})

print(df.head())
# Out:
#    Patient ID  Age  Gender Ethnicity Marital Status Education Level  \
# 0        1018   32  Female   African         Single    Some College
# 1        2406   69    Male   African       Divorced    Some College
# 2        1188   57    Male  Hispanic       Divorced  College Degree
# 3        6200   27  Female  Hispanic        Married  College Degree
# 4        5824   56  Female  Hispanic        Married     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# 0         2016-07-15                            203                MDD
# 1         2017-04-28                            180               None
# 2         2018-02-02                            173                MDD
# 3         2014-08-25                            126               PTSD
# 4         2022-02-20                            168               PTSD
#
#   Family History of OCD Obsession Type Compulsion Type  \
# 0                    No   Harm-related        Checking
# ...

# %% [markdown]
# # Finding Outliers

# %%
# Plotting boxplots for each attribute
plt.figure(figsize=(10, 8))
df[['Age','Gender', 'Duration of Symptoms (months)', 'Y-BOCS Score (Obsessions)', 'Y-BOCS Score (Compulsions)']].plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), patch_artist=True, notch=True)
plt.suptitle('Boxplots of OCD')
plt.show()


# There is no outliers in the dataset.

# %%
**Interpretation**

*  There is no outliers in the dataset.
* There is no need to do the Normalization.

# %% [markdown]
# # Detecting the null values

# %%
### Setting annot to true gives us the numbers in each cell.

sns.heatmap(df.isnull(), yticklabels=False, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Inconsistant column Names
# ### Change case
# ### Rename Them

# %%
df.columns = df.columns.str.upper()
df.columns
# Out:
# Index(['PATIENT ID', 'AGE', 'GENDER', 'ETHNICITY', 'MARITAL STATUS',
#        'EDUCATION LEVEL', 'OCD DIAGNOSIS DATE',
#        'DURATION OF SYMPTOMS (MONTHS)', 'PREVIOUS DIAGNOSES',
#        'FAMILY HISTORY OF OCD', 'OBSESSION TYPE', 'COMPULSION TYPE',
#        'Y-BOCS SCORE (OBSESSIONS)', 'Y-BOCS SCORE (COMPULSIONS)',
#        'DEPRESSION DIAGNOSIS', 'ANXIETY DIAGNOSIS', 'MEDICATIONS',
#        'Y-BOCS SEVERITY'],
#       dtype='object')

# %% [markdown]
# ### Rename

# %%
df.rename(columns = {'DURATION OF SYMPTOMS (MONTHS)':'TIME OF SYMPTOMS (MONTHS)'})
# Out:
#       PATIENT ID  AGE  GENDER  ETHNICITY MARITAL STATUS  EDUCATION LEVEL  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD DIAGNOSIS DATE  TIME OF SYMPTOMS (MONTHS) PREVIOUS DIAGNOSES  \
# ...

# %% [markdown]
# # Data transformation

# %% [markdown]
# ### There is no duplicates

# %%
### checking duplicates

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       PATIENT ID  AGE  GENDER  ETHNICITY MARITAL STATUS  EDUCATION LEVEL  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD DIAGNOSIS DATE  DURATION OF SYMPTOMS (MONTHS) PREVIOUS DIAGNOSES  \
# ...

# %%
df.shape
# Out:
# (1500, 17)

# %%
# What is the average age of the patients

# %%
average_age = df['AGE'].mean()
print(f'Average age of patients is : {average_age}')
# Out:
# Average age of patients is : 46.781333333333336

# %%
# What is the distribution of patients' gender?

# %%
gender_distribution = df['GENDER'].value_counts()
print("The distribution of patients' gender is:\n", gender_distribution)
# Out:
# The distribution of patients' gender is:
#  Male      753
# Female    747
# Name: GENDER, dtype: int64

# %%
# How does the ethnic composition of the patient population break down?

# %%
ethnicity_composition = df['ETHNICITY'].value_counts()
print("The ethnic composition of the patient population is:\n", ethnicity_composition)
# Out:
# The ethnic composition of the patient population is:
#  Caucasian    398
# Hispanic     392
# Asian        386
# African      324
# Name: ETHNICITY, dtype: int64

# %%
# What is the marital status distribution among the patients?

# %%
marital_status_distribution = df['MARITAL STATUS'].value_counts()

# Display the distribution
print(marital_status_distribution)
# Out:
# Single      511
# Married     507
# Divorced    482
# Name: MARITAL STATUS, dtype: int64

# %%
# Group by age and marital status, and count the occurrences
age_marital_distribution = df.groupby(['MEDICATIONS', 'MARITAL STATUS']).size().unstack(fill_value=0)

print(age_marital_distribution)
# Out:
# MARITAL STATUS  Divorced  Married  Single
# MEDICATIONS
# Benzodiazepine       122      129     135
# None                 118      139     129
# SNRI                 130      120     126
# SSRI                 112      119     121

# %%
# Find the highest level of education
highest_education = df['EDUCATION LEVEL'].max()

print("Highest level of education attained by the patients:", highest_education)
# Out:
# Highest level of education attained by the patients: Some College

# %%
# convert the data type 'DiagnosisDate' to datetime
df['OCD DIAGNOSIS DATE'] = pd.to_datetime(df['OCD DIAGNOSIS DATE'], format='%Y-%m-%d')
df
# Out:
#       PATIENT ID  AGE  GENDER  ETHNICITY MARITAL STATUS  EDUCATION LEVEL  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD DIAGNOSIS DATE  DURATION OF SYMPTOMS (MONTHS) PREVIOUS DIAGNOSES  \
# ...

# %%
df.head(5)
# Out:
#    PATIENT ID  AGE  GENDER ETHNICITY MARITAL STATUS EDUCATION LEVEL  \
# 0        1018   32  Female   African         Single    Some College
# 1        2406   69    Male   African       Divorced    Some College
# 2        1188   57    Male  Hispanic       Divorced  College Degree
# 3        6200   27  Female  Hispanic        Married  College Degree
# 4        5824   56  Female  Hispanic        Married     High School
#
#   OCD DIAGNOSIS DATE  DURATION OF SYMPTOMS (MONTHS) PREVIOUS DIAGNOSES  \
# 0         2016-07-15                       0.841880                MDD
# 1         2017-04-28                       0.743590               None
# 2         2018-02-02                       0.713675                MDD
# 3         2014-08-25                       0.512821               PTSD
# 4         2022-02-20                       0.692308               PTSD
#
#   FAMILY HISTORY OF OCD OBSESSION TYPE COMPULSION TYPE  \
# 0                    No   Harm-related        Checking
# ...

# %%
# Scatter plot for 'Y-BOCS Score (Obsessions)' vs. 'Y-BOCS Score (Compulsions)'
sns.scatterplot(x='Y-BOCS SCORE (OBSESSIONS)', y='Y-BOCS SCORE (COMPULSIONS)', data=df)
plt.title('Y-BOCS Score (Obsessions) vs. Y-BOCS Score (Compulsions)')
plt.xlabel('Y-BOCS Score (Obsessions)')
plt.ylabel('Y-BOCS Score (Compulsions)')
plt.show()

# %%
### The above graph is not understandable because the data points are normalized
#     which makes it harder to see patterns or correlations.


### These **(Y-BOCS Score (Obsessions) and Y-BOCS Score (Compulsions))** scores are typically integers, 
#     it seems decimal values indicates, the data might have been altered.

# %% [markdown]
# ###  plotting with original integer values. This make the relationship between the two variables more apparent.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with original (non-scaled) values
plt.figure(figsize=(10, 6))
sns.regplot(x='Y-BOCS SCORE (OBSESSIONS)', y='Y-BOCS SCORE (COMPULSIONS)', data=df, scatter_kws={'s': 20}, line_kws={'color': 'red'})

plt.title('Scatter Plot with Regression Line: Y-BOCS Score (Obsessions) vs. Y-BOCS Score (Compulsions)', fontsize=16)
plt.xlabel('Y-BOCS Score (Obsessions)', fontsize=14)
plt.ylabel('Y-BOCS Score (Compulsions)', fontsize=14)

plt.show()

# %%
# Interpretation

### The line indicates.

### If the line slopes upwards, it indicates a positive correlation.
### If the line slopes downwards, it indicates a negative correlation.
### If the line is almost flat, then it is weak (or) no correlation between the variables.


### In this case, the line is nearly flat,
#    which suggests that there is little to no linear relationship between the 
#    Y-BOCS Score (Obsessions) and the Y-BOCS Score (Compulsions). 
#    This means that changes in one score are not strongly associated with changes in the other score.

# %% [markdown]
# # Objective

# %% [markdown]
# # Investigating the demographic distribution of OCD patients

# %%
# The frequency of patients in different age groups

# %%
import pandas as pd

# Define age bins and labels
age_bins = [0, 20, 40, 60, 80]
age_labels = ['0-20', '21-40', '41-60', '61+']

# Create a new column with age group labels
df['AGE GROUP'] = pd.cut(df['AGE'], bins=age_bins, labels=age_labels, right=False)
# 'pd.cut' is a pandas function that segments and sorts data values into bins.

# Calculate the frequency of each age group
age_group_distribution = df['AGE GROUP'].value_counts().sort_index()

print(age_group_distribution)
# Out:
# 0-20      50
# 21-40    517
# 41-60    518
# 61+      415
# Name: AGE GROUP, dtype: int64

# %%
# Which gender is most effected in age group 41 to 60.

# %%
# Filter for the age group 41-60
age_filtered = df[df['AGE GROUP'] == '41-60']

# Count the occurrences of each gender in the filtered dataset
gender_counts = age_filtered['GENDER'].value_counts()

print(gender_counts)
# Out:
# Male      259
# Female    259
# Name: GENDER, dtype: int64

# %% [markdown]
# **Interpretation**
#
# * from 41 - 60 age group patients of male and female are same effected.

# %%
# Filter for the age group 41-60
age_filtered = df[df['AGE GROUP'] == '21-40']

# Count the occurrences of each gender in the filtered dataset
gender_counts = age_filtered['GENDER'].value_counts()

print(gender_counts)
# Out:
# Male      263
# Female    254
# Name: GENDER, dtype: int64

# %% [markdown]
# **Interpretation**
#
# * In the age group 21 - 40 patients of Male is mostly effected than Female.

# %%
# Interpretation

# In the age group max which gender is effected


# Group by Age Group and Gender and count occurrences
grouped_data = df.groupby(['AGE GROUP', 'GENDER']).size().unstack() # each combination of Age Group and GENDER appears as a pair.

# Plotting the graph
grouped_data.plot(kind='bar', stacked=True)
plt.title('Gender Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Interpretation**
#
#  * From above more '41 - 60' and '21 - 40' group patients have high OCD effected people.

# %% [markdown]
# # Objective
#
# ### Determine the gender ratio in the OCD patient population.

# %%
import pandas as pd

# Step 1: Total number of patients
total_patients = df.shape[0]

# Step 2: Count the number of male patients
male_patients = df[df['GENDER'] == 'Male'].shape[0]

# Step 3: Count the number of female patients
female_patients = df[df['GENDER'] == 'Female'].shape[0]

# Step 4: Calculate the percentage of male and female patients
male_percentage = (male_patients / total_patients) * 100
female_percentage = (female_patients / total_patients) * 100

# Print the results
print(f"Total Patients: {total_patients}")
print(f"Male Patients: {male_patients} ({male_percentage:.2f}%)")
print(f"Female Patients: {female_patients} ({female_percentage:.2f}%)")
# Out:
# Total Patients: 1500
# Male Patients: 753 (50.20%)
# Female Patients: 747 (49.80%)

# %% [markdown]
# **Interpretation**
#
# * From the above total patients are 1500 and more (more distributed)Male_patients are effected to OCD 4%(0.40) more than Female_patients.

# %% [markdown]
# # Objective:
#
# ### Analyze the ethnic composition of the OCD patients.

# %%
Total_patients = df.shape[0]

Ethnicity = df['ETHNICITY'].value_counts()

African_patient = df[df['ETHNICITY'] == 'African'].shape[0]

Hispanic_patient = df[df['ETHNICITY'] == 'Hispanic'].shape[0]

Asian_patient = df[df['ETHNICITY'] == 'Asian'].shape[0]

Caucasian_patient = df[df['ETHNICITY'] == 'Caucasian'].shape[0]

African_percentage = (African_patient / Total_patients)* 100
Hispanic_percentage = (Hispanic_patient / Total_patients)*100
Asian_percentage = (Asian_patient / Total_patients)*100
Caucasian_percentage = (Caucasian_patient / Total_patients)*100

print(f"African_percentage : {African_patient} ({African_percentage:.2f}%)")
print(f"Hispanic_percentage : {Hispanic_patient} ({Hispanic_percentage:.2f}%)")
print(f"Asian_percentage : {Asian_patient} ({Asian_percentage:.2f}%)")
print(f"Caucasian_percentage : {Caucasian_patient} ({Caucasian_percentage:.2f}%)")
# Out:
# African_percentage : 324 (21.60%)
# Hispanic_percentage : 392 (26.13%)
# Asian_percentage : 386 (25.73%)
# Caucasian_percentage : 398 (26.53%)

# %% [markdown]
# **Interpretation**
#
# * The Caucasian people mostly effected by OCD.
# * Secondly Hispanic people are effected.
# * Thirdly Asian people.
# * Fourthly African people is affected.

# %% [markdown]
# # Objective:
#
# ### Explore the marital status of the OCD patients to see if there's a common trend.

# %%
# Step 1: Total number of patients
total_patients = df.shape[0]

# Step 2: Count the number of patients in each marital status
marital_status_count = df['MARITAL STATUS'].value_counts()

# Step 3: Calculate the percentage for each marital status
marital_status_percentage = (marital_status_count / total_patients) * 100

# Print the results
print("Marital Status Distribution:")
print(marital_status_percentage)
# Out:
# Marital Status Distribution:
# Single      34.066667
# Married     33.800000
# Divorced    32.133333
# Name: MARITAL STATUS, dtype: float64

# %% [markdown]
# **Interpretation**
#
# * From above single people are mostly effected by OCD.
# * Secondly Married people are effected.
# * Thirdly Divorced people are effected.

# %% [markdown]
# # Objective:
#
# ### Investigate the education levels among OCD patients.

# %%
# Step 1: Total number of patients
total_patients = df.shape[0]

# Step 2: Count the number of patients in each education level
education_level_count = df['EDUCATION LEVEL'].value_counts()

# Step 3: Calculate the percentage for each education level
education_level_percentage = (education_level_count / total_patients) * 100

# Print the results
print("Education Level Distribution:")
print(education_level_percentage)
# Out:
# Education Level Distribution:
# Some College       26.266667
# Graduate Degree    25.066667
# College Degree     24.400000
# High School        24.266667
# Name: EDUCATION LEVEL, dtype: float64

# %% [markdown]
# **Interpretation**
#
# * From above
# * Firstly 'Some College' people are mostly effected.
# * Secondly 'Graduate Degree' people are effected by OCD.
# * Thirdly 'College Degree' people are effected by OCD.
# * Fourthly 'High School' people are effected ny OCD.

# %%
## Containg the maximum effected demographic distribution amoung the OCD patients.

# %%
High_demographic = df[
    (df['GENDER'] == 'Male') & 
    (df['ETHNICITY'] == 'Caucasian') & 
    (df['MARITAL STATUS'] == 'Single') & 
    (df['EDUCATION LEVEL'] == 'Some College')
]

# %%
High_demographic
# Out:
#       PATIENT ID  AGE GENDER  ETHNICITY MARITAL STATUS EDUCATION LEVEL  \
# 26          5366   47   Male  Caucasian         Single    Some College
# 165         7662   50   Male  Caucasian         Single    Some College
# 168         3449   31   Male  Caucasian         Single    Some College
# 510         6729   33   Male  Caucasian         Single    Some College
# 512         9637   23   Male  Caucasian         Single    Some College
# 518         3246   68   Male  Caucasian         Single    Some College
# 674         9751   41   Male  Caucasian         Single    Some College
# 727         1380   40   Male  Caucasian         Single    Some College
# 739         2617   37   Male  Caucasian         Single    Some College
# 1070        7397   71   Male  Caucasian         Single    Some College
# 1078        3343   39   Male  Caucasian         Single    Some College
# 1085        5656   57   Male  Caucasian         Single    Some College
# ...

# %%
High_demographic.count()
# Out:
# PATIENT ID                       15
# AGE                              15
# GENDER                           15
# ETHNICITY                        15
# MARITAL STATUS                   15
# EDUCATION LEVEL                  15
# OCD DIAGNOSIS DATE               15
# DURATION OF SYMPTOMS (MONTHS)    15
# PREVIOUS DIAGNOSES               15
# FAMILY HISTORY OF OCD            15
# OBSESSION TYPE                   15
# COMPULSION TYPE                  15
# Y-BOCS SCORE (OBSESSIONS)        15
# Y-BOCS SCORE (COMPULSIONS)       15
# DEPRESSION DIAGNOSIS             15
# ANXIETY DIAGNOSIS                15
# MEDICATIONS                      15
# Y-BOCS SEVERITY                  15
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# The distribution of ages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of ages
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Ages in the OCD Dataset')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# No.of males and females are represented.

# %%
gender_counts = df['Gender'].value_counts()

# Display the results
print(gender_counts)
# Out:
# Male      753
# Female    747
# Name: Gender, dtype: int64

# %%
# Plotting the bar graph
gender_counts = df['Gender'].value_counts()

plt.bar(gender_counts.index, gender_counts.values, color=['skyblue', 'pink'])
plt.title('Distribution of Males and Females in the Dataset')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#  The most common ethnicity.

# %%
# Count the occurrences of each ethnicity
ethnicity_counts = df['Ethnicity'].value_counts()
ethnicity_counts

# Get the most common ethnicity
most_common_ethnicity = ethnicity_counts.idxmax()
print(most_common_ethnicity)
# Out:
# Caucasian

# %%
ethnicity_counts = df['Ethnicity'].value_counts()

# Plotting the bar graph
plt.figure(figsize=(8, 6))
ethnicity_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Ethnicities in the Dataset')
plt.xlabel('Ethnicity')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
#  The predominant marital status among the patients.

# %%
# Count the occurrences of each marital status
marital_status_counts = df['Marital Status'].value_counts()

# Find the predominant marital status
predominant_marital_status = marital_status_counts.idxmax()
predominant_marital_status
# Out:
# 'Single'

# %%
marital_status_counts = df['Marital Status'].value_counts()

# Plot the bar chart
plt.figure(figsize=(8, 6))
marital_status_counts.plot(kind='bar', color='red')
plt.title('Distribution of Marital Status in OCD Dataset')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#  The distribution of education levels among the patients

# %%
education_counts = df['Education Level'].value_counts()
education_counts

# most common education_counts.
common = education_counts.idxmax()
common
# Out:
# 'Some College'

# %%
education_counts = df['Education Level'].value_counts()

# Plotting the distribution of education levels
education_counts = df['Education Level'].value_counts()
education_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# No of patients have a family history of OCD.

# %%
# The shape[0] gives the number of rows in this filtered DataFrame, which corresponds to the number of patients with a family history of OCD.


# Count the number of patients with a family history of OCD
family_history_count = df[df['Family History of OCD'] == 'Yes'].shape[0]
family_history_count
# Out:
# 760

# %%
# Count the number of patients with a family history of OCD
family_history_counts = df['Family History of OCD'].value_counts()

# Plotting a bar graph
family_history_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Patients with Family History of OCD')
plt.xlabel('Family History of OCD')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# The different types of obsessions and compulsions reported by the patients.

# %%
unique_obsessions = df['Obsession Type'].unique()
unique_compulsions = df['Compulsion Type'].unique()

# Print the unique values
print(unique_obsessions)

print(unique_compulsions)
# Out:
# ['Harm-related' 'Contamination' 'Symmetry' 'Hoarding' 'Religious']
# ['Checking' 'Washing' 'Ordering' 'Praying' 'Counting']

# %%
obsession_counts = df['Obsession Type'].value_counts()

# Create a bar chart for obsessions
plt.figure(figsize=(12, 6))
sns.barplot(x=obsession_counts.index, y=obsession_counts.values, palette='viridis')
plt.title('Distribution of Obsession Types')
plt.xlabel('Obsession Types')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
compulsion_counts = df['Compulsion Type'].value_counts()

# Create a bar chart for compulsions
plt.figure(figsize=(12, 6))
sns.barplot(x=compulsion_counts.index, y=compulsion_counts.values, palette='viridis')
plt.title('Distribution of Compulsion Types')
plt.xlabel('Compulsion Types')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()
